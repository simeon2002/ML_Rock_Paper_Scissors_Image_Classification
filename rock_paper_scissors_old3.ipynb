# %% [markdown]
# # Redistribute Dataset split
# Currente is bad 33 files inside of validation folder. There are in total 2926 images which needs to be redistributed into a 70:15:15 **random** split. Currently there are 2521 images in the train folder, 33 in the validation folder, and 372 in the test folder.
#
# *Note: the shuffling only happened once. Once code is re-executed, the same images will be present in the corresponding folder!*

# %%
import os
import random
import shutil

# Seed for reproducibility
random.seed(42)

# Function to clear the contents of a directory
def clear_directory(directory):
    if os.path.exists(directory):
        shutil.rmtree(directory)  # Deletes the directory and its contents
    os.makedirs(directory, exist_ok=True)  # Recreates the directory

# Directories
base_dir = "./Rock-Paper-Scissors"
train_dir = os.path.join(base_dir, "train")
val_dir = os.path.join(base_dir, "validation")
test_dir = os.path.join(base_dir, "test")

# Temporary directory to consolidate all images
temp_dir = os.path.join(base_dir, "all_images")
clear_directory(temp_dir)

# Target directories for the final split
new_train_dir = os.path.join(base_dir, "resplit_train")
new_val_dir = os.path.join(base_dir, "resplit_validation")
new_test_dir = os.path.join(base_dir, "resplit_test")

# Clear existing directories
clear_directory(new_train_dir)
clear_directory(new_val_dir)
clear_directory(new_test_dir)

# Step 1: Consolidate all images into one folder
def consolidate_images(src_dir, temp_dir, class_name=None):
    for root, _, files in os.walk(src_dir):
        for file in files:
            if file.endswith(('.png', '.jpg', '.jpeg')):
                src_path = os.path.join(root, file)
                if class_name:  # Add class name as prefix for validation images
                    dst_path = os.path.join(temp_dir, f"{class_name}_{file}")
                else:
                    dst_path = os.path.join(temp_dir, file)
                shutil.copy(src_path, dst_path)

# Consolidate images from train, test, and validation folders
for class_name in ["scissors", "paper", "rock"]:
    consolidate_images(os.path.join(train_dir, class_name), temp_dir, class_name)
    consolidate_images(os.path.join(test_dir, class_name), temp_dir, class_name)
consolidate_images(val_dir, temp_dir)  # Validation images are directly in this folder

# Step 2: Split images into train, validation, and test
all_images = os.listdir(temp_dir)
random.shuffle(all_images)

# Calculate exact split sizes
total_images = len(all_images)
train_size = int(total_images * 0.7)
remaining = total_images - train_size
val_size = remaining // 2
test_size = remaining - val_size

# Check and print sizes
print(f"Training size: {train_size}, Validation size: {val_size}, Test size: {test_size}")

# Split the images
train_images = all_images[:train_size]
val_images = all_images[train_size:train_size + val_size]
test_images = all_images[train_size + val_size:]

# Step 3: Move images to the new directories
def move_images(image_list, target_dir, no_subfolders=False):
    for img in image_list:
        src_path = os.path.join(temp_dir, img)
        if "_" in img and not no_subfolders:  # For train and test, keep subfolders
            class_name = img.split("_")[0]
            class_dir = os.path.join(target_dir, class_name)
            os.makedirs(class_dir, exist_ok=True)
            shutil.move(src_path, os.path.join(class_dir, img))
        else:  # For validation, move images directly
            shutil.move(src_path, os.path.join(target_dir, img))

# Move images to their respective folders
move_images(train_images, new_train_dir)
move_images(val_images, new_val_dir, no_subfolders=True)  # No subfolders for validation
move_images(test_images, new_test_dir)

# Remove temporary directory after use
shutil.rmtree(temp_dir)

print("Resplit completed!")
# Out:
# Training size: 2048, Validation size: 439, Test size: 439
# Resplit completed!

# %% [markdown]
# Validate **new split in resplit_XXX directories**

# %%
def count_images_in_split(target_dir):
    for split in ["resplit_train", "resplit_validation", "resplit_test"]:
        split_dir = os.path.join(base_dir, split)
        total_images = sum([len(files) for _, _, files in os.walk(split_dir)])
        print(f"{split.capitalize()} Set: {total_images} images")

count_images_in_split(base_dir)

# %% [markdown]
# # Preprocessing
# Fetch data and create test, validation and training datasets

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras import regularizers
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt


class_names = ["paper", "rock", "scissors"]

def fetch_val_dataset(class_names, val_dir):
    ''' 
    Fetch images from specified dir and process to grayscale and appropriate dims
    '''

    class_to_index = {class_name: i for i, class_name in enumerate(class_names)} # provide index for each label.
    
    # process images and store into array with corresponding labels
    images = []
    labels = []
    
    for file_name in os.listdir(val_dir):
        if file_name.endswith(('.png', '.jpg', '.jpeg')):
            # extract label from filename.
            label = next((name for name in class_names if name in file_name.lower()), None) 
            if label is not None:
                # Construct the full path to the image
                file_path = os.path.join(val_dir, file_name)
    
                # Process image, i.e. graysale, resize and normalize!!
                with Image.open(file_path).convert("L") as img: #note: L grayscale image
                    img = img.resize((300,300))
                    img_array = np.array(img) / 255.0
                    images.append(img_array)
    
            # append label's index.
            labels.append(class_to_index[label])

    # convert ot numpy arrays
    X = np.array(images, dtype="float32") # shape = each sample with 60x60 array
    Y = np.array(labels, dtype="int32") # shape is num of samples, 1

    # add channel dimension to images (for grayscale input)
    X = np.expand_dims(X, axis=-1)

    return X, Y

def visualize_tf_dataset(dataset, class_names, title="Dataset Samples"):
    '''
    Visualize samples of tf_dataset dtype
    '''
    plt.figure(figsize=(10, 10))
    for images, labels in dataset.take(1):  # Take one batch
        for i in range(9):  # Show 9 samples
            plt.subplot(3, 3, i + 1)
            plt.imshow(images[i].numpy().squeeze(), cmap="gray")  # Grayscale images
            plt.title(class_names[labels[i].numpy()])
            plt.axis("off")
    plt.suptitle(title)
    plt.show()

def plot_numpy_dataset(X, Y, class_names, title="Validation Dataset Samples"):
    '''
    Visualize samples of Numpy array dtype
    '''
    plt.figure(figsize=(10, 10))
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.imshow(X[i].squeeze(), cmap="gray")
        plt.title(class_names[Y[i]])
        plt.axis("off")
    plt.suptitle(title)
    plt.show()



# Set paths for train, validation, and test directories
train_dir = "./Rock-Paper-Scissors/resplit_train"
val_dir = "./Rock-Paper-Scissors/resplit_validation"
test_dir = "./Rock-Paper-Scissors/resplit_test"

# Load datasets
'''
    creates pixels in grayscale 60x60 mode with a 32 batch size. 
    and note: labels => automatically inferred.
'''

train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(300, 300),  
    color_mode="grayscale",  
    batch_size=64           
)

X_val, Y_val = fetch_val_dataset(class_names, val_dir)
print(f"Validation images shape: {X_val.shape}")  # Example: (33, 300, 300, 1)
print(f"Validation labels shape: {Y_val.shape}")  # Example: (33,)


test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(300, 300),
    color_mode="grayscale",  
    batch_size=64
)

# Rescale pixels
normalization_layer = layers.Rescaling(1./255)

train_dataset = train_dataset.map(lambda x, y: (normalization_layer(x), y))
test_dataset = test_dataset.map(lambda x, y: (normalization_layer(x), y))


# Shuffle and prefetch for efficiency
AUTOTUNE = tf.data.AUTOTUNE # prefetching => used to make loading data and preprocessing async to model training
train_dataset = train_dataset.shuffle(1000).prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, Y_val)).batch(64).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# 2024-12-10 16:48:52.997126: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-10 16:48:53.039763: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 2024 files belonging to 3 classes.
# Validation images shape: (439, 300, 300, 1)
# Validation labels shape: (439,)
# Found 432 files belonging to 3 classes.

# %% [markdown]
# Visualize samples of each dataset to check correctness of preprocessing

# %%
#check whether preprocessing is succesfull by checking a couple of samples
visualize_tf_dataset(train_dataset, class_names, title="Training Dataset Samples")
visualize_tf_dataset(test_dataset, class_names, title="Test Dataset Samples")
plot_numpy_dataset(X_val, Y_val, class_names, title="Validation Dataset Samples")
# Out:
# 2024-12-10 16:49:10.644975: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-12-10 16:49:11.397222: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# # 1. NN implementaton
# **manually tuned neurons and layers, regularization and learning rate automatically optimzied (cv_loss VS train_loss compared)**
#
# In this implementation a NN model will be created, fitted and optimized to classify the images

# %% [markdown]
# ### Model implementation
# - [x] Implement manually tuned NN model (went from one layer 256 -> 256,128,64, -> 256,128,128 -> 256, 64, 64 -> 128,64,64) => epoch = 50, learning rate = 0.01, no regularization, no early stopping, no lr_schedule yet, batch size 64, adam optimizer, sparsecategorical loss function)
# - [x] tuned further through learning rate optimize to remove spikes from the learning rate due to overshoot and outliers in batches.
# - [x] added learning rate schedule to optimize learning rate even further at lower error values where noise became more significant
# - [x] configure regularization by testing different values + have a plot
# - [ ] todo: configure learning rate and batch size as well + have a plot
#
# note: this is the fully connected NN (FCNN) model which won't be as fast as a CNN model!

# %%
model = Sequential([
    layers.Flatten(input_shape=(300, 300, 1)),  # Input layer to flatten the image
    layers.Dense(128, activation='relu', name="L1"),  # Increased neurons
    layers.Dense(64, activation='relu', name="L2"),
    layers.Dense(64, activation='relu', name="L3"),
    layers.Dense(3, activation='softmax', name="output"),  # Output layer for 3 classes
    ],
    name="FCNN_manual"
)

# reducing learning rate => address spike issues in losses
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    learning_rate=0.0001,
    decay_steps=1000,
    decay_rate=0.9
)

# Compile the model
model.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule), 
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "FCNN_manual"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_13 (Flatten)            │ (None, 90000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ L1 (Dense)                      │ (None, 128)            │    11,520,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ L2 (Dense)                      │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ L3 (Dense)                      │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,532,739 (43.99 MB)
#  Trainable params: 11,532,739 (43.99 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train model

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=100,
    restore_best_weights=True
)

# Train the model
history = model.fit(
    train_dataset,
    validation_data=val_dataset,  # Use the validation dataset
    epochs=200,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9981 - loss: 0.0139 - val_accuracy: 0.9863 - val_loss: 0.0603
# Epoch 2/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9912 - loss: 0.0286 - val_accuracy: 1.0000 - val_loss: 0.0169
# Epoch 3/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.9960 - loss: 0.0170 - val_accuracy: 0.9977 - val_loss: 0.0145
# Epoch 4/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.9779 - loss: 0.0610 - val_accuracy: 0.8565 - val_loss: 0.3815
# Epoch 5/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8872 - loss: 0.3041 - val_accuracy: 0.9886 - val_loss: 0.0471
# Epoch 6/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.9736 - loss: 0.0734 - val_accuracy: 0.9886 - val_loss: 0.0460
# Epoch 7/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9968 - loss: 0.0225 - val_accuracy: 0.9954 - val_loss: 0.0207
# Epoch 8/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.9980 - loss: 0.0139 - val_accuracy: 0.9954 - val_loss: 0.0210
# Epoch 9/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9979 - loss: 0.0133 - val_accuracy: 0.9954 - val_loss: 0.0209
# Epoch 10/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9982 - loss: 0.0141 - val_accuracy: 0.9932 - val_loss: 0.0190
# Epoch 11/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9987 - loss: 0.0104 - val_accuracy: 0.9954 - val_loss: 0.0210
# Epoch 12/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.9977 - loss: 0.0114 - val_accuracy: 0.9954 - val_loss: 0.0132
# Epoch 13/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.9975 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 14/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9995 - loss: 0.0083 - val_accuracy: 0.9954 - val_loss: 0.0137
# Epoch 15/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9992 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 0.0171
# Epoch 16/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9994 - loss: 0.0081 - val_accuracy: 0.9954 - val_loss: 0.0147
# Epoch 17/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9989 - loss: 0.0084 - val_accuracy: 0.9977 - val_loss: 0.0129
# Epoch 18/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9997 - loss: 0.0070 - val_accuracy: 0.9977 - val_loss: 0.0124
# Epoch 19/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9996 - loss: 0.0087 - val_accuracy: 0.9932 - val_loss: 0.0210
# Epoch 20/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9996 - loss: 0.0073 - val_accuracy: 1.0000 - val_loss: 0.0107
# Epoch 21/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0099
# Epoch 22/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9988 - loss: 0.0057 - val_accuracy: 0.9977 - val_loss: 0.0117
# Epoch 23/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9985 - loss: 0.0080 - val_accuracy: 0.9977 - val_loss: 0.0119
# Epoch 24/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9994 - loss: 0.0055 - val_accuracy: 0.9977 - val_loss: 0.0151
# Epoch 25/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9997 - loss: 0.0066 - val_accuracy: 0.9954 - val_loss: 0.0113
# Epoch 26/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0104
# Epoch 27/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9999 - loss: 0.0045 - val_accuracy: 0.9954 - val_loss: 0.0222
# Epoch 28/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.9999 - loss: 0.0079 - val_accuracy: 0.9977 - val_loss: 0.0108
# Epoch 29/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0092
# Epoch 30/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9954 - val_loss: 0.0143
# Epoch 31/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9981 - loss: 0.0079 - val_accuracy: 0.9977 - val_loss: 0.0114
# Epoch 32/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.9994 - loss: 0.0059 - val_accuracy: 0.9977 - val_loss: 0.0086
# Epoch 33/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9995 - loss: 0.0046 - val_accuracy: 0.9954 - val_loss: 0.0125
# Epoch 34/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9977 - val_loss: 0.0084
# Epoch 35/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.9982 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0078
# Epoch 36/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9999 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0086
# Epoch 37/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9977 - val_loss: 0.0083
# Epoch 38/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9977 - val_loss: 0.0083
# Epoch 39/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.9979 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0078
# Epoch 40/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9977 - val_loss: 0.0090
# Epoch 41/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9996 - loss: 0.0051 - val_accuracy: 0.9954 - val_loss: 0.0087
# Epoch 42/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.9987 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0083
# Epoch 43/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9954 - val_loss: 0.0155
# Epoch 44/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9992 - loss: 0.0063 - val_accuracy: 0.9909 - val_loss: 0.0300
# Epoch 45/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9987 - loss: 0.0074 - val_accuracy: 0.9795 - val_loss: 0.0676
# Epoch 46/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9920 - loss: 0.0320 - val_accuracy: 0.9909 - val_loss: 0.0220
# Epoch 47/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9990 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 0.0148
# Epoch 48/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9983 - loss: 0.0088 - val_accuracy: 0.9909 - val_loss: 0.0241
# Epoch 49/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9971 - loss: 0.0120 - val_accuracy: 0.9977 - val_loss: 0.0128
# Epoch 50/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 51/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 52/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 53/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 54/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9954 - val_loss: 0.0104
# Epoch 55/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9977 - val_loss: 0.0065
# Epoch 56/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9998 - loss: 0.0033 - val_accuracy: 0.9977 - val_loss: 0.0100
# Epoch 57/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 58/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 59/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 60/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 61/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9977 - val_loss: 0.0053
# Epoch 62/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 63/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 64/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 65/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 66/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 67/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9977 - val_loss: 0.0056
# Epoch 68/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 69/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9977 - val_loss: 0.0080
# Epoch 70/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.9992 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 71/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9991 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0093
# Epoch 72/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 73/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 74/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 75/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 76/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 77/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 78/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 79/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 80/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 81/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9954 - val_loss: 0.0116
# Epoch 82/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 83/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 84/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9954 - val_loss: 0.0091
# Epoch 85/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 86/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 87/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 88/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 89/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 90/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 91/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 92/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9977 - val_loss: 0.0041
# Epoch 93/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 94/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 8.6597e-04 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 95/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 1.0000 - loss: 9.0256e-04 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 96/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 97/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 98/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 99/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 9.9586e-04 - val_accuracy: 0.9977 - val_loss: 0.0043
# Epoch 100/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 1.0000 - loss: 8.6490e-04 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 101/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 8.7743e-04 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 102/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 9.3460e-04 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 103/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 8.9814e-04 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 104/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 8.1554e-04 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 105/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 106/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 8.9976e-04 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 107/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 7.8299e-04 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 108/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 7.0805e-04 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 109/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 9.1608e-04 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 110/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9993 - loss: 0.0028 - val_accuracy: 0.9590 - val_loss: 0.1169
# Epoch 111/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9156 - loss: 0.2548 - val_accuracy: 0.9180 - val_loss: 0.1989
# Epoch 112/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9230 - loss: 0.2516 - val_accuracy: 0.9886 - val_loss: 0.0499
# Epoch 113/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9947 - loss: 0.0272 - val_accuracy: 0.9954 - val_loss: 0.0148
# Epoch 114/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9996 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0115
# Epoch 115/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.9977 - val_loss: 0.0120
# Epoch 116/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9998 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 117/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0099
# Epoch 118/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9954 - val_loss: 0.0125
# Epoch 119/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 0.0100
# Epoch 120/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0102
# Epoch 121/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 122/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9977 - val_loss: 0.0124
# Epoch 123/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9977 - val_loss: 0.0097
# Epoch 124/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 0.0089
# Epoch 125/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0088
# Epoch 126/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0081
# Epoch 127/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 128/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9977 - val_loss: 0.0087
# Epoch 129/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 130/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0076
# Epoch 131/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 132/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 133/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 134/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9954 - val_loss: 0.0089
# Epoch 135/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 136/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 137/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 138/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 139/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 140/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 141/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 142/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 143/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 144/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 145/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9977 - val_loss: 0.0067
# Epoch 146/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 147/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 148/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9954 - val_loss: 0.0100
# Epoch 149/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 150/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 151/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 152/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 153/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9977 - val_loss: 0.0065
# Epoch 154/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 155/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 156/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 157/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 158/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 159/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 160/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 161/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 162/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 163/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 164/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 165/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 166/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 167/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 168/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 169/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 170/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 171/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 172/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 173/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 174/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 175/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 176/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 177/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 178/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 179/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9977 - val_loss: 0.0054
# Epoch 180/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 181/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 182/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 9.7503e-04 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 183/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 184/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 185/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 186/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 187/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9977 - val_loss: 0.0058
# Epoch 188/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 9.3469e-04 - val_accuracy: 0.9977 - val_loss: 0.0046
# Epoch 189/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 9.8925e-04 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 190/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 8.3114e-04 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 191/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 1.0000 - loss: 9.4368e-04 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 192/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 8.9716e-04 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 193/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 9.5268e-04 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 194/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 195/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 9.1006e-04 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 196/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 197/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 1.0000 - loss: 7.6743e-04 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 198/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 9.6234e-04 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 199/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 8.9390e-04 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 200/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 9.4694e-04 - val_accuracy: 1.0000 - val_loss: 0.0033

# %% [markdown]
# ### Predict with model and visualize training and validation results

# %%
# Plot accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim(0, 0.5)  # Replace ymin and ymax with your desired limits
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluate model with test dataset

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test Accuracy: {test_acc}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0016
# Test Accuracy: 1.0

# %%
# Evaluate one batch of training data
for X_batch, Y_batch in train_dataset.take(1):
    train_loss, train_acc = model.evaluate(X_batch, Y_batch, verbose=0)
    print(f"Train Loss: {train_loss}, Train Accuracy: {train_acc}")

# Evaluate the validation data
val_loss, val_acc = model.evaluate(X_val, Y_val, verbose=0)
print(f"Validation Loss: {val_loss}, Validation Accuracy: {val_acc}")
# Out:
# Train Loss: 0.0005232493858784437, Train Accuracy: 1.0
# 2024-12-10 17:38:36.556322: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation Loss: 0.0030048321932554245, Validation Accuracy: 1.0

# %% [markdown]
# ### Visualize results
# predicatoins vs label for a couple of sapmles

# %%
def plot_predictions(model, dataset, class_names, num_samples=9):
    """
    Plot sample images, showing their true labels and predicted labels.
    Args:
        model: Trained model for making predictions.
        dataset: The dataset (tf.data.Dataset or (X, Y) tuple) to draw samples from.
        class_names: List of class names corresponding to labels.
        num_samples: Number of images to display.
    """
    # Prepare the dataset
    if isinstance(dataset, tuple):  # For (X, Y) datasets like validation
        images, labels = dataset
    else:  # For tf.data.Dataset
        images, labels = next(iter(dataset.take(1)))
    
    predictions = model.predict(images)
    predicted_labels = np.argmax(predictions, axis=1)
    
    # Plot samples
    plt.figure(figsize=(10, 10))
    for i in range(num_samples):
        plt.subplot(10, 6, i + 1)
        img = images[i].numpy().squeeze()  # Remove batch/channel dimensions if present
        plt.imshow(img, cmap="gray" if img.ndim == 2 else None)  # Handle grayscale or RGB
        true_label = class_names[labels[i]]
        pred_label = class_names[predicted_labels[i]]
        plt.title(f"True: {true_label}\nPred: {pred_label}")
        plt.axis("off")
    plt.tight_layout()
    plt.show()

# %%
class_names = ["paper", "rock", "scissors"]  # Match your dataset labels

# Plot predictions on validation dataset
plot_predictions(model, val_dataset, class_names, num_samples=40)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %% [markdown]
# ## Optimization of hyperparamaters

# %% [markdown]
# ### Regularization
# As a first, lambda will be optimized to determine what the best value for lambda would be for in order to optimize the model even more if possible.

# %%
tf.random.set_seed(1234)

# Define regularization strengths
lambdas = [0.0, 0.001, 0.01, 0.05, 0.1, 0.2, 0.3]
models = [None] * len(lambdas)

train_errors = []
val_errors = []
val_accuracies = []
train_accuracies = []

# Iterate through each lambda
for i, lambda_ in enumerate(lambdas):
    print(f"Training model with lambda = {lambda_}")
    
    # Define the model
    models[i] = Sequential([
        layers.Flatten(input_shape=(300, 300, 1)),  # Input layer
        layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(lambda_)),
        layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(lambda_)),
        layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(lambda_)),
        layers.Dense(3, activation='softmax')  # Output layer
    ])
    
    # Learning rate schedule
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=0.001,
        decay_steps=1000,
        decay_rate=0.9
    )
    
    # Compile the model
    models[i].compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
        metrics=['accuracy']
    )
    
    # Early stopping
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    )
    
    # Train the model
    history = models[i].fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=200,
        callbacks=[early_stopping],
        verbose=0
    )
    
    # # Save the final training and validation losses
    # train_errors.append(history.history['loss'][-1])
    # val_errors.append(history.history['val_loss'][-1])

    # Save train and validation losses of the best weights that were chosen (i.e. where the loss was minimal)
    train_loss, train_acc = models[i].evaluate(train_dataset, verbose=0)
    val_loss, val_acc = models[i].evaluate(val_dataset, verbose=0)
    train_errors.append(train_loss)
    val_errors.append(val_loss)
    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    
    print(f"Finished lambda = {lambda_}")

# Plot training and validation errors
plt.figure(figsize=(8, 6))
plt.plot(lambdas, train_errors, marker='o', label="Train Error")
plt.plot(lambdas, val_errors, marker='o', label="Validation Error")
plt.xscale('log')
plt.xlabel("Regularization (lambda)")
plt.ylabel("Error (Loss)")
plt.title("Tuning Regularization: Train vs Validation Error")
plt.legend()
plt.show()
# Out:
# Training model with lambda = 0.0
# Finished lambda = 0.0
# Training model with lambda = 0.001
# Finished lambda = 0.001
# Training model with lambda = 0.01
# Finished lambda = 0.01
# Training model with lambda = 0.05
# Finished lambda = 0.05
# Training model with lambda = 0.1
# Finished lambda = 0.1
# Training model with lambda = 0.2
# Finished lambda = 0.2
# Training model with lambda = 0.3
# Finished lambda = 0.3

# %%
min_val = min(val_errors)
max_accuracy = max(val_accuracies)
for i, err in enumerate(val_errors):
    print(f"For lambda = {lambdas[i]} the training error is {train_errors[i]} and the validation error is {err} a validation accuracy of {val_accuracies[i]}")
    if err == min_val:
        print("Where the error is the smallest here.")
    if val_accuracies[i] == max_accuracy:
        print("AND here, the accuracy is the highest.")
# Out:
# For lambda = 0.0 the training error is 0.07638977468013763 and the validation error is 0.09044582396745682 a validation accuracy of 0.9703872203826904
# Where the error is the smallest here.
# For lambda = 0.001 the training error is 0.16598986089229584 and the validation error is 0.1713765561580658 a validation accuracy of 0.9954441785812378
# AND here, the accuracy is the highest.
# For lambda = 0.01 the training error is 0.9141218662261963 and the validation error is 0.9288983345031738 a validation accuracy of 0.9293849468231201
# For lambda = 0.05 the training error is 2.278827428817749 and the validation error is 2.3044393062591553 a validation accuracy of 0.9043279886245728
# For lambda = 0.1 the training error is 0.9543148875236511 and the validation error is 0.9396249055862427 a validation accuracy of 0.8906605839729309
# For lambda = 0.2 the training error is 1.1466156244277954 and the validation error is 1.1465400457382202 a validation accuracy of 0.2984054684638977
# For lambda = 0.3 the training error is 1.1051712036132812 and the validation error is 1.1086466312408447 a validation accuracy of 0.2984054684638977

# %% [markdown]
# **Conclusion: regularization parameter value of 0 will be best as it has the smallest error**

# %% [markdown]
# ### Learning rate
# Next, the learning rate alpha will be optimized to determine what the best value for alpha would be to optimize the model even more if possible.
# note: learning scehduling is removed to tune fixed learning rate.

# %%
tf.random.set_seed(1234)

# Define learning rates
learning_rates = [0.0001, 0.0003, 0.001, 0.003, 0.01]
models = [None] * len(learning_rates)

train_errors = []
val_errors = []
val_accuracies = []
train_accuracies = []

# Iterate through each learning rate
for i, learning_rate in enumerate(learning_rates):
    print(f"Training model with learning rate = {learning_rate}")
    
    # Define the model
    models[i] = Sequential([
        layers.Flatten(input_shape=(300, 300, 1)),  # Input layer
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(3, activation='softmax')  # Output layer
    ])
    
    # # Learning rate schedule
    # lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #     learning_rate=learning_rate,
    #     decay_steps=1000,
    #     decay_rate=0.9
    # )
    
    # Compile the model
    models[i].compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
        metrics=['accuracy']
    )
    
    # Early stopping
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    )
    
    # Train the model
    history = models[i].fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=200,
        callbacks=[early_stopping],
        verbose=1
    )
    
    # Save train and validation losses of the best weights
    train_loss, train_acc = models[i].evaluate(train_dataset, verbose=0)
    val_loss, val_acc = models[i].evaluate(val_dataset, verbose=0)
    train_errors.append(train_loss)
    val_errors.append(val_loss)
    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    
    print(f"Finished learning rate = {learning_rate}")

plt.plot(learning_rates, train_errors, marker='o', label="Train Error")
plt.plot(learning_rates, val_errors, marker='o', label="Validation Error")
plt.xscale('log')
plt.xlabel("Learning Rate (alpha))")
plt.ylabel("Error (Loss)")
plt.title("Tuning Learning Rate: Train vs Validation Error")
plt.legend()
plt.show()

# %%
print(val_errors)
print(train_errors)
print(learning_rates)
print(val_accuracies)
# smallest_error = val_errors[0]
# best_learning_rate = learning_rates[0]
# for i, val_error in enumerate(val_errors):
#     if val_error < smallest_error:
#         best_learning_rate = learning_rates[i]

plt.plot(learning_rates, train_errors, marker='o', label="Train Error")
plt.plot(learning_rates, val_errors, marker='o', label="Validation Error")
plt.xscale('log')
plt.xlabel("Learning Rate (alpha))")
plt.ylabel("Error (Loss)")
plt.title("Tuning Learning Rate: Train vs Validation Error")
plt.legend()
plt.show()
# Out:
# [0.09044582396745682, 0.1713765561580658, 0.9288983345031738, 2.3044393062591553, 0.9396249055862427, 1.1465400457382202, 1.1086466312408447]
# [0.07638977468013763, 0.16598986089229584, 0.9141218662261963, 2.278827428817749, 0.9543148875236511, 1.1466156244277954, 1.1051712036132812]
# [0.0001, 0.0003, 0.001, 0.003, 0.01]
# [0.9703872203826904, 0.9954441785812378, 0.9293849468231201, 0.9043279886245728, 0.8906605839729309, 0.2984054684638977, 0.2984054684638977]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 11
#       4 print(val_accuracies)
#       5 # smallest_error = val_errors[0]
#       6 # best_learning_rate = learning_rates[0]
#       7 # for i, val_error in enumerate(val_errors):
#       8 #     if val_error < smallest_error:
#       9 #         best_learning_rate = learning_rates[i]
# ---> 11 plt.plot(learning_rates, train_errors, marker='o', label="Train Error")
#      12 plt.plot(learning_rates, val_errors, marker='o', label="Validation Error")
#      13 plt.xscale('log')
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
#    1726     self.add_line(line)
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (5,) and (7,)

# %% [markdown]
# Conclusion: use a value of 0.001 for the learning rate as was the case already.

# %% [markdown]
# # 2. NN implementaton with automatic optimization
# **automatically tuned neurons and layers, regularization and learning rate automatically optimzied (cv_loss VS train_loss compared)**
# note: it is still to be determined where to use grid search to tune multiple hyperparameters at once or do each hyperparameter one by one.
#
# In this implementation another NN model will be created, fitted and optimized to classify the images

# %% [markdown]
# ## Default model
# This is the starting, default model from which the optimization will start.
# TODO LATER, FIRST SIMULATENOUS OPTIMIZATION

# %% [markdown]
# ## Optimization of layers and neurons
# ### Individual approach
# In this approach the layers and neurons will be optimized separately based on their validation loss to train loss value

# %% [markdown]
# ### Simulatenous approach
# In this approach the layers and neurons will be optimized simulatenously looking at all possible combinations in a layer and neuron range.

# %% [markdown]
# #### Create the models

# %%
import os
import numpy as np
from tensorflow.keras.models import save_model, load_model
from tensorflow.keras import Sequential, layers
import tensorflow as tf

# Directory to save models
model_dir = "saved_models"
os.makedirs(model_dir, exist_ok=True)

# Define grid of layers and neurons
layer_options = [1, 2, 3, 4]  # Number of layers
neuron_options = [32, 64, 128, 256]  # Number of neurons per layer

# Iterate through each configuration
for num_layers in layer_options:
    for num_neurons in neuron_options:
        print(f"Training model with {num_layers} layers and {num_neurons} neurons per layer")

        # Build the model
        model = Sequential()
        model.add(layers.Flatten(input_shape=(300, 300, 1)))  # Input layer
        for _ in range(num_layers):
            model.add(layers.Dense(num_neurons, activation='relu'))
        model.add(layers.Dense(3))  # Output layer with linear activation (logits)

        # Compile the model
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
            loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),  # Use logits during training
            metrics=['accuracy']
        )

        # Early stopping
        early_stopping = tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=10,
            restore_best_weights=True
        )

        # Train the model
        model.fit(
            train_dataset,
            validation_data=val_dataset,
            epochs=200,
            callbacks=[early_stopping],
            verbose=1
        )

        # Save the model in the native Keras format
        model_name = f"model_{num_layers}L_{num_neurons}N.keras"
        save_model(model, os.path.join(model_dir, model_name))
        print(f"Model saved: {model_name}")
# Out:
# Training model with 1 layers and 64 neurons per layer
# Epoch 1/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.3270 - loss: 45.7212 - val_accuracy: 0.3645 - val_loss: 11.4765
# Epoch 2/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5331 - loss: 5.5535 - val_accuracy: 0.7130 - val_loss: 2.0192
# Epoch 3/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7110 - loss: 1.4584 - val_accuracy: 0.8200 - val_loss: 0.8202
# Model saved: model_1L_64N.keras
# Training model with 1 layers and 128 neurons per layer
# Epoch 1/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.3268 - loss: 72.4968 - val_accuracy: 0.5649 - val_loss: 1.3086
# Epoch 2/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.6359 - loss: 0.9063 - val_accuracy: 0.7950 - val_loss: 0.5178
# Epoch 3/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7785 - loss: 0.5587 - val_accuracy: 0.7973 - val_loss: 0.5414
# Model saved: model_1L_128N.keras
# Training model with 1 layers and 256 neurons per layer
# Epoch 1/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - accuracy: 0.3648 - loss: 71.3626 - val_accuracy: 0.3964 - val_loss: 3.7147
# Epoch 2/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.5243 - loss: 2.2633 - val_accuracy: 0.6401 - val_loss: 0.9883
# Epoch 3/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.7292 - loss: 0.7570 - val_accuracy: 0.4100 - val_loss: 2.2811
# Model saved: model_1L_256N.keras
# Training model with 2 layers and 64 neurons per layer
# Epoch 1/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.3189 - loss: 13.7953 - val_accuracy: 0.3121 - val_loss: 3.5912
# Epoch 2/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.4777 - loss: 2.0820 - val_accuracy: 0.5626 - val_loss: 4.1175
# Epoch 3/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6207 - loss: 1.6046 - val_accuracy: 0.8588 - val_loss: 0.4379
# Model saved: model_2L_64N.keras
# Training model with 2 layers and 128 neurons per layer
# Epoch 1/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.3494 - loss: 20.9258 - val_accuracy: 0.4032 - val_loss: 6.7036
# Epoch 2/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.4274 - loss: 4.4932 - val_accuracy: 0.7403 - val_loss: 0.8955
# Epoch 3/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.6741 - loss: 1.3163 - val_accuracy: 0.8405 - val_loss: 0.5303
# Model saved: model_2L_128N.keras
# Training model with 2 layers and 256 neurons per layer
# Epoch 1/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.3248 - loss: 69.4099 - val_accuracy: 0.3895 - val_loss: 6.1910
# Epoch 2/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.4120 - loss: 5.1875 - val_accuracy: 0.5831 - val_loss: 1.7637
# Epoch 3/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.5428 - loss: 2.0701 - val_accuracy: 0.6674 - val_loss: 0.9030
# Model saved: model_2L_256N.keras
# Training model with 3 layers and 64 neurons per layer
# Epoch 1/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.3358 - loss: 7.0064 - val_accuracy: 0.3121 - val_loss: 3.9199
# Epoch 2/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.4612 - loss: 2.1163 - val_accuracy: 0.7380 - val_loss: 0.6432
# Epoch 3/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6285 - loss: 0.8498 - val_accuracy: 0.6925 - val_loss: 0.7540
# Model saved: model_3L_64N.keras
# Training model with 3 layers and 128 neurons per layer
# Epoch 1/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.3494 - loss: 15.3589 - val_accuracy: 0.2984 - val_loss: 7.6242
# Epoch 2/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4112 - loss: 3.5296 - val_accuracy: 0.4738 - val_loss: 1.1402
# Epoch 3/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6096 - loss: 0.8475 - val_accuracy: 0.5125 - val_loss: 1.0680
# Model saved: model_3L_128N.keras
# Training model with 3 layers and 256 neurons per layer
# Epoch 1/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.3322 - loss: 38.4272 - val_accuracy: 0.3121 - val_loss: 7.3957
# Epoch 2/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.3450 - loss: 7.4372 - val_accuracy: 0.3371 - val_loss: 3.6341
# Epoch 3/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.4406 - loss: 2.2342 - val_accuracy: 0.5718 - val_loss: 1.0474
# Model saved: model_3L_256N.keras

# %% [markdown]
# #### Load and evaluate models

# %%
# Define evaluation function
def eval_cat_err(y_true, y_pred_logits):
    """
    Calculate the categorization error.
    Args:
        y_true : (ndarray or Tensor) True labels.
        y_pred_logits : (ndarray or Tensor) Predicted logits.
    Returns:
        cerr: (scalar) Categorization error (fraction of incorrect predictions).
    """
    y_pred_probs = tf.nn.softmax(y_pred_logits).numpy()  # Apply softmax to logits
    y_pred_classes = np.argmax(y_pred_probs, axis=1)
    incorrect = np.sum(y_true != y_pred_classes)
    m = len(y_true)
    cerr = incorrect / m
    return cerr

# Load models and evaluate
results = []
for num_layers in layer_options:
    for num_neurons in neuron_options:
        model_name = f"model_{num_layers}L_{num_neurons}N.keras"
        model_path = os.path.join(model_dir, model_name)

        # Load the model
        model = load_model(model_path)
        print(f"Loaded model: {model_name}")

        # Collect true labels from datasets
        y_train = np.concatenate([y for _, y in train_dataset], axis=0)
        y_val = np.concatenate([y for _, y in val_dataset], axis=0)

        # Predict logits
        train_logits = model.predict(train_dataset)
        val_logits = model.predict(val_dataset)

        # Calculate categorization errors
        train_cerr = eval_cat_err(y_train, train_logits)
        val_cerr = eval_cat_err(y_val, val_logits)

        # Store results
        results.append({
            'num_layers': num_layers,
            'num_neurons': num_neurons,
            'train_cerr': train_cerr,
            'val_cerr': val_cerr
        })

        print(f"Train Error: {train_cerr:.4f}, Validation Error: {val_cerr:.4f}")

# Visualize results (optional)
for result in results:
    print(result)
# Out:
# Loaded model: model_1L_64N.keras
# 2024-12-11 04:16:44.661349: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-12-11 04:16:44.697644: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Train Error: 0.6764, Validation Error: 0.1800
# Loaded model: model_1L_128N.keras
# 2024-12-11 04:16:53.098146: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-12-11 04:16:53.131529: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Train Error: 0.6630, Validation Error: 0.2050
# Loaded model: model_1L_256N.keras
# 2024-12-11 04:17:05.368364: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-12-11 04:17:05.397858: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Train Error: 0.6591, Validation Error: 0.3599
# Loaded model: model_2L_64N.keras
# 2024-12-11 04:17:13.657666: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-12-11 04:17:13.696253: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Train Error: 0.6522, Validation Error: 0.1412
# Loaded model: model_2L_128N.keras
# 2024-12-11 04:17:22.420557: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-12-11 04:17:22.461942: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Train Error: 0.6635, Validation Error: 0.1595
# Loaded model: model_2L_256N.keras
# 2024-12-11 04:17:35.829802: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-12-11 04:17:35.894840: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Train Error: 0.6823, Validation Error: 0.3326
# Loaded model: model_3L_64N.keras
# 2024-12-11 04:17:43.932642: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-12-11 04:17:43.966676: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Train Error: 0.6596, Validation Error: 0.2620
# Loaded model: model_3L_128N.keras
# 2024-12-11 04:17:51.074689: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-12-11 04:17:51.103452: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Train Error: 0.6665, Validation Error: 0.4875
# Loaded model: model_3L_256N.keras
# 2024-12-11 04:18:02.242747: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-12-11 04:18:02.270403: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Train Error: 0.6645, Validation Error: 0.4282
# {'num_layers': 1, 'num_neurons': 64, 'train_cerr': 0.6763833992094862, 'val_cerr': 0.17995444191343962}
# {'num_layers': 1, 'num_neurons': 128, 'train_cerr': 0.6630434782608695, 'val_cerr': 0.20501138952164008}
# {'num_layers': 1, 'num_neurons': 256, 'train_cerr': 0.6590909090909091, 'val_cerr': 0.35990888382687924}
# {'num_layers': 2, 'num_neurons': 64, 'train_cerr': 0.6521739130434783, 'val_cerr': 0.14123006833712984}
# {'num_layers': 2, 'num_neurons': 128, 'train_cerr': 0.6635375494071146, 'val_cerr': 0.15945330296127563}
# {'num_layers': 2, 'num_neurons': 256, 'train_cerr': 0.6823122529644269, 'val_cerr': 0.3325740318906606}
# {'num_layers': 3, 'num_neurons': 64, 'train_cerr': 0.6595849802371542, 'val_cerr': 0.2619589977220957}
# {'num_layers': 3, 'num_neurons': 128, 'train_cerr': 0.666501976284585, 'val_cerr': 0.4874715261958998}
# {'num_layers': 3, 'num_neurons': 256, 'train_cerr': 0.6645256916996047, 'val_cerr': 0.428246013667426}

# %% [markdown]
# #### Visualize results
# Here we have a heatmap in order to visualize the results as the layer and neurons configs are all optimized at once

# %%
import seaborn as sns

# Heatmap for training error
plt.figure(figsize=(10, 8))
sns.heatmap(
    train_errors,
    annot=True,
    fmt=".4f",
    xticklabels=neuron_options,
    yticklabels=layer_options,
    cmap="Blues",
    cbar_kws={'label': 'Train Error'}
)
plt.title("Training Error Heatmap")
plt.xlabel("Number of Neurons")
plt.ylabel("Number of Layers")
plt.scatter(best_neuron_idx + 0.5, best_layer_idx + 0.5, color='red', s=100, label="Best Configuration")
plt.legend()
plt.show()

# Heatmap for validation error
plt.figure(figsize=(10, 8))
sns.heatmap(
    val_errors,
    annot=True,
    fmt=".4f",
    xticklabels=neuron_options,
    yticklabels=layer_options,
    cmap="Oranges",
    cbar_kws={'label': 'Validation Error'}
)
plt.title("Validation Error Heatmap")
plt.xlabel("Number of Neurons")
plt.ylabel("Number of Layers")
plt.scatter(best_neuron_idx + 0.5, best_layer_idx + 0.5, color='red', s=100, label="Best Configuration")
plt.legend()
plt.show()

# Combined Error Comparison (Optional)
plt.figure(figsize=(12, 6))
for i, layer_count in enumerate(layer_options):
    plt.plot(
        neuron_options,
        train_errors[i, :],
        label=f"Train Error (Layers={layer_count})",
        marker='o'
    )
    plt.plot(
        neuron_options,
        val_errors[i, :],
        label=f"Val Error (Layers={layer_count})",
        linestyle='--',
        marker='x'
    )
plt.title("Train vs Validation Errors Across Neurons and Layers")
plt.xlabel("Number of Neurons")
plt.ylabel("Categorization Error")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### Determine best configuration

# %%
# Find the best configuration based on the minimum validation error
min_val_error = np.min(val_errors)
best_config_indices = np.where(val_errors == min_val_error)
best_layer_idx = best_config_indices[0][0]
best_neuron_idx = best_config_indices[1][0]

best_num_layers = layer_options[best_layer_idx]
best_num_neurons = neuron_options[best_neuron_idx]

print(f"Best Configuration:")
print(f" - Number of Layers: {best_num_layers}")
print(f" - Number of Neurons: {best_num_neurons}")
print(f" - Validation Error: {min_val_error:.4f}")
print(f" - Training Error: {train_errors[best_layer_idx, best_neuron_idx]:.4f}")
# Out:
# Best Configuration:
#  - Number of Layers: 2
#  - Number of Neurons: 64
#  - Validation Error: 0.1412
#  - Training Error: 0.6522

# %% [markdown]
# # Camera Predictions

# %% [markdown]
# # import cv2
#
# ```python
# def predict_from_camera(model, class_names):
#     """
#     Use the camera to capture live frames, preprocess them, and predict using the trained model.
#     Args:
#         model: Trained model for predictions.
#         class_names: List of class names.
#     """
#     # Open a connection to the webcam
#     cap = cv2.VideoCapture(0)  # 0 for the default camera
#
#     if not cap.isOpened():
#         print("Error: Unable to access the camera.")
#         return
#
#     print("Press 'q' to quit the webcam feed.")
#
#     while True:
#         ret, frame = cap.read()
#         if not ret:
#             print("Error: Unable to capture a frame.")
#             break
#
#         # Convert the frame to grayscale and resize to the model's input size
#         gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#         resized_frame = cv2.resize(gray_frame, (300, 300))
#         normalized_frame = resized_frame / 255.0  # Normalize pixel values
#         input_frame = np.expand_dims(normalized_frame, axis=(0, -1))  # Add batch and channel dimensions
#
#         # Predict using the model
#         predictions = model.predict(input_frame)
#         predicted_label = np.argmax(predictions, axis=1)[0]
#         confidence = np.max(predictions)
#
#         # Display the prediction on the video feed
#         label_text = f"Prediction: {class_names[predicted_label]} ({confidence:.2f})"
#         cv2.putText(frame, label_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
#
#         # Show the video feed
#         cv2.imshow("Camera Feed", frame)
#
#         # Press 'q' to quit
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
#
#     # Release the camera and close all OpenCV windows
#     cap.release()
#     cv2.destroyAllWindows()
#
# # Call the function
# predict_from_camera(model, class_names)
# ```

# %% [markdown]
# # comparison using minimum loss vs accuracy (categroical error) to evaluate best model!!
# ### Calculating Errors by Summing All Losses
# You're absolutely correct that taking the sum of all losses during training/validation gives a better representation of the overall error than just taking the minimum loss. The rationale is:
#
# Minimum Loss: Reflects only the best point but doesn't account for fluctuations or spikes across epochs.
# Summed Loss: Captures the aggregate performance of the model over all epochs, providing a more robust metric for comparison.
# By summing losses, you evaluate the total error incurred across the training/validation process, making it a better proxy for overall model performance.
#
# ### Why the Previous Comparisons Are Not a Big Problem
# Loss and classification error are both valid metrics, and their trends often correlate.
# However, classification error (accuracy-based) is more intuitive for tasks like classification, where the primary goal is to minimize misclassifications.
